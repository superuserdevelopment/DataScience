# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df1 = pd.read_excel('Data_Train.xlsx')
df1 = pd.read_excel('Data_Train.xlsx',na_values=[np.nan])
# Dropping New_Price due to irreglar Data
df1 = df1.drop(['New_Price'],axis=1)
df1 = df1[df1['Engine'] != float]
df1 = df1[df1['Power'] != float]
Power = [];
Engine = [];
for ind in df1.index:
    s = df1['Engine'][ind]
    p = df1['Engine'][ind]
    if(type(s)!=float and type(p)!=float):
        s = s[:s.find('C')-1] 
        p = p[:p.find('C')-1]
    if(s == 'null'or p=='null'):
        df2 = df2.drop(ind)
        continue
    s = float(s)
    p = float(p)
    Engine.append(s)
    Power.append(p)
df1.drop(['Engine'],axis=1)
df1['Engine(CC)']=Engine
df1.drop(['Power'],axis=1)
df1['Power(BHP)'] = Power
df1
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
sentence = 'b a hello b Hi'
h = sentence.rsplit(' b ', 1)
h[0]
# Out:
# 'b a hello'

# %%
df2 = df1[df1['Fuel_Type']=='Petrol']
df3 = df2[df2['Transmission'] == 'Manual']
df2 = df2[df2['Transmission'] == 'Automatic']
df3
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 2                      Honda Jazz V     Chennai  2011              46000
# 10                 Maruti Ciaz Zeta       Kochi  2018              25692
# 23            Hyundai i20 1.2 Magna     Kolkata  2010              45807
# 25     Honda City Corporate Edition      Mumbai  2012              51920
# 27    Maruti Alto K10 2010-2014 VXI   Hyderabad  2013              54000
# ...                             ...         ...   ...                ...
# 6002  Volkswagen Vento 1.6 Highline      Mumbai  2011              38000
# 6003             Maruti Celerio VXI   Bangalore  2015              67600
# 6004               Hyundai Getz GLE  Coimbatore  2007              66800
# 6010           Honda Brio 1.2 VX MT       Delhi  2013              33746
# 6017             Maruti Wagon R VXI     Kolkata  2013              46000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# ...

# %%
brands = [];
for ind in df1.index:
    s = df1['Name'][ind]
    s = s[:s.find(' ')] 
    brands.append(s)
# brands = brands.set()
brands = list(set(brands))
brands
# Out:
# ['BMW',
#  'Mitsubishi',
#  'Jaguar',
#  'Audi',
#  'Datsun',
#  'Maruti',
#  'Nissan',
#  'Toyota',
#  'Lamborghini',
#  'Renault',
#  'Hyundai',
#  'Bentley',
#  'Land',
#  'ISUZU',
#  'Tata',
#  'Mahindra',
#  'Mercedes-Benz',
#  'Fiat',
#  'Honda',
#  'Ambassador',
#  'Mini',
#  'Smart',
#  'Chevrolet',
#  'Porsche',
#  'Isuzu',
#  'Jeep',
#  'Ford',
#  'Force',
#  'Volvo',
#  'Skoda',
#  'Volkswagen']

# %%
# Python program to demonstrate 
# KNN classification algorithm 
# on IRIS dataser 
  
from sklearn.datasets import load_iris 
from sklearn.neighbors import KNeighborsClassifier 
import numpy as np 
from sklearn.model_selection import train_test_split 
  
#iris_dataset=load_iris() 
  
#X_train, X_test, y_train, y_test = train_test_split(iris_dataset["data"], iris_dataset["target"], random_state=0) 
  
df2 = df1[['Name','Price']]
y_train = df2['Name'].values.reshape(-1,1)
X_train = df2['Price'].values.reshape(-1,1)    
kn = KNeighborsClassifier(n_neighbors=1) 
kn.fit(X_train, y_train) 
  
x_new = np.array(X_train) 
prediction = kn.predict(x_new) 
  
print("Predicted target value: {}\n".format(prediction)) 
print("Predicted feature name: {}\n".format(prediction)) 
# print("Test score: {:.2f}".format(kn.score(X_test, y_test)))
