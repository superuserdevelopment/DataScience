# %% [markdown]
# # Importing Dataset

# %%
import math as math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('ncov2019.csv',na_values=[np.nan])
df1.head()
# Out:
#   Province/State Country/Region      Lat      Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN       Thailand  15.0000  101.0000        2        3        5
# 1            NaN          Japan  36.0000  138.0000        2        1        2
# 2            NaN      Singapore   1.2833  103.8333        0        1        3
# 3            NaN          Nepal  28.1667   84.2500        0        0        0
# 4            NaN       Malaysia   2.5000  112.5000        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/14/20  3/15/20  3/16/20  3/17/20  \
# 0        7        8        8  ...       82      114      147      177
# 1        2        4        4  ...      773      839      825      878
# 2        3        4        5  ...      212      226      243      266
# 3        1        1        1  ...        1        1        1        1
# 4        3        4        4  ...      238      428      566      673
#
#    3/18/20  3/19/20  3/20/20  3/21/20  3/22/20  3/23/20
# ...

# %% [markdown]
# # Data Cleaning

# %%
k = 0
for i in df1.columns:
    if(k<4):
        k=k+1
    else:
        #print(i)
        for j in df1[i]:
            if(isinstance(j, float) and not(math.isnan(j))):
                j = int(j)
            elif(math.isnan(j)):
                j = 0
            #print(type(j),j)
print("Data types uniforming done")

k = 0
for i in df1.columns:
    if(k<4):
        k=k+1
    else:
        total = 0
        zeros = 0
        #print(i)
        for j in df1[i]:
            if(j == 0):
                zeros = zeros + 1
            total = total + 1
        #print("total is:",total,"Zeros are: ",zeros,"Percentage:",zeros/total)
        
        if(zeros/total >= 0.7):
            print("Dropping Column:",i)
            df1 = df1.drop([i],axis = 1)
print("Removing Entries done")
df1
# Out:
# Data types uniforming done
# Dropping Column: 1/22/20
# Dropping Column: 1/23/20
# Dropping Column: 1/24/20
# Dropping Column: 1/25/20
# Dropping Column: 1/26/20
# Dropping Column: 1/27/20
# Dropping Column: 1/28/20
# Dropping Column: 1/29/20
# Dropping Column: 1/30/20
# Dropping Column: 1/31/20
# Dropping Column: 2/1/20
# Dropping Column: 2/2/20
# Dropping Column: 2/3/20
# Dropping Column: 2/4/20
# Dropping Column: 2/5/20
# Dropping Column: 2/6/20
# Dropping Column: 2/7/20
# Dropping Column: 2/8/20
# Dropping Column: 2/9/20
# Dropping Column: 2/10/20
# Dropping Column: 2/11/20
# Dropping Column: 2/12/20
# Dropping Column: 2/13/20
# Dropping Column: 2/14/20
# Dropping Column: 2/15/20
# Dropping Column: 2/16/20
# Dropping Column: 2/17/20
# Dropping Column: 2/18/20
# Dropping Column: 2/19/20
# Dropping Column: 2/20/20
# Dropping Column: 2/21/20
# Dropping Column: 2/22/20
# Dropping Column: 2/23/20
# Dropping Column: 2/24/20
# Dropping Column: 2/25/20
# Dropping Column: 2/26/20
# ...

# %% [markdown]
# # Plotting Graphs

# %% [markdown]
# ## Country vs Number of Cases on a particular date

# %%
x = df1['Country/Region']
y = df1['3/23/20']
print(max(y))

#plt.rcParams['figure.figsize'] = (100,20)
df2 = pd.DataFrame()
df2['Country'] = x
df2['Cases']=y
df2 = df2[df2['Cases']>500]
x = df2['Country']
y = df2['Cases']
plt.bar(x,y)
#df2.set_index('Country')
# Out:
# 67800.0
# <BarContainer object of 60 artists>

# %%
import seaborn as sns
sns.set(style="whitegrid")
#sns.lmplot(x='Country',y='Cases',data=df2)

sns.barplot(x='Country', y='Cases', data=df2)

# %% [markdown]
# ## Date vs Cases for a single Country

# %%
df3 = df1[df1['Country/Region'] == 'Italy']
df3 = df3.drop(['Province/State','Country/Region','Lat','Long'],axis=1)
df3.reset_index().drop(['index'],axis=1)
df4 = pd.DataFrame()
df4['Date'] = df3.columns
df4['Cases'] = list(df3.iloc[0])
df4
# Out:
#        Date    Cases
# 0    3/4/20   3089.0
# 1    3/5/20   3858.0
# 2    3/6/20   4636.0
# 3    3/7/20   5883.0
# 4    3/8/20   7375.0
# 5    3/9/20   9172.0
# 6   3/10/20  10149.0
# 7   3/11/20  12462.0
# 8   3/12/20  12462.0
# 9   3/13/20  17660.0
# 10  3/14/20  21157.0
# 11  3/15/20  24747.0
# 12  3/16/20  27980.0
# 13  3/17/20  31506.0
# 14  3/18/20  35713.0
# 15  3/19/20  41035.0
# 16  3/20/20  47021.0
# 17  3/21/20  53578.0
# 18  3/22/20  59138.0
# 19  3/23/20  59138.0

# %%
x = df4['Date']
y = df4['Cases']
plt.plot(x,y)
plt.xlabel('Dates')
plt.ylabel('Cases')
plt.title("Date vs Cases for Italy")
# Out:
# Text(0.5, 1.0, 'Date vs Cases for Italy')

# %%
import seaborn as sns
sns.set(style="whitegrid")
#sns.lmplot(x='Country',y='Cases',data=df2)
sns.barplot(x='Date', y='Cases', data=df4)
